# %%
import sys
sys.path.append('C:\\Users\\louis\\Documents\\Codes\\GAC\\OpenIO-Canada\\')
import openIO
import pandas as pd
import numpy as np
# Out:
# C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\openIO.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# To get the data from openIO-Canada, you simply need to enter 3 arguments:
# - the path to the STATCAN economic data (Detailed level) for the year you chose (available here: https://www150.statcan.gc.ca/n1/en/catalogue/15-602-X). **Make sure to download the Excel versions for the code to work properly.**
# - the path to an IOT pxp folder of Exiobase. Exiobase data can be found here: https://doi.org/10.5281/zenodo.5589597
# - a boolean whether you wish to endogenize capitals or not. The default option is that they are endogenized. For more information on endogenization of capitals, read these articles: (https://doi.org/10.1021/acs.est.8b02791)
# (https://doi.org/10.1111/jiec.12931). **Note that endogenization introduces a lot of uncertainties, but that not endogenizing capitals will result in emission factors not including the impact of infrastructure and in an underestimation of total emissions at provincial or national level.**

# %%
tables = openIO.IOTables(folder_path='C:\\Users\\louis\\Documents\\Codes\\GAC\\OpenIO-Canada\\Data\\StatsCan\\2022\\Detail level\\',
                         exiobase_folder='C:\\Users\\louis\\Documents\\Codes\\GAC\\OpenIO-Canada\\Data\\EXIOBASE\\IOT_2022_pxp\\',
                         endogenizing_capitals=False)
# Out:
# 2026-01-06 07:07:31,114 - openIO-Canada - INFO - Reading all the Excel files...
# 2026-01-06 07:07:38,870 - openIO-Canada - INFO - Formatting the Supply and Use tables...
# 2026-01-06 07:07:58,088 - openIO-Canada - INFO - Modifying names of duplicated sectors...
# 2026-01-06 07:07:58,336 - openIO-Canada - INFO - Organizing final demand sectors...
# 2026-01-06 07:07:59,277 - openIO-Canada - INFO - Removing IOIC codes from index...
# 2026-01-06 07:07:59,366 - openIO-Canada - INFO - Balancing inter-provincial trade...
# 2026-01-06 07:08:55,254 - openIO-Canada - INFO - Loading Exiobase...
# 2026-01-06 07:08:55,255 - INFO - Starting to parse Exiobase data...
# 2026-01-06 07:08:55,287 - INFO - Read metadata from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\metadata.json
# 2026-01-06 07:08:55,287 - INFO - 20260106 07:08:55 - FILEIO -  Loaded IO system from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp
# 2026-01-06 07:08:55,288 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\Z.txt
# 2026-01-06 07:09:08,101 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\Y.txt
# 2026-01-06 07:09:09,346 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\x.txt
# 2026-01-06 07:09:09,425 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\A.txt
# 2026-01-06 07:09:21,190 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\unit.txt
# 2026-01-06 07:09:21,360 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\air_emissions\F.txt
# 2026-01-06 07:09:22,177 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\air_emissions\F_Y.txt
# 2026-01-06 07:09:22,246 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\air_emissions\unit.txt
# 2026-01-06 07:09:22,269 - INFO - 20260106 07:09:22 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\air_emissions
# 2026-01-06 07:09:22,293 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\employment\F.txt
# 2026-01-06 07:09:22,487 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\employment\F_Y.txt
# 2026-01-06 07:09:22,657 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\employment\unit.txt
# 2026-01-06 07:09:22,659 - INFO - 20260106 07:09:22 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\employment
# 2026-01-06 07:09:22,661 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\factor_inputs\F.txt
# 2026-01-06 07:09:22,830 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\factor_inputs\F_Y.txt
# 2026-01-06 07:09:22,872 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\factor_inputs\unit.txt
# 2026-01-06 07:09:22,874 - INFO - 20260106 07:09:22 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\factor_inputs
# 2026-01-06 07:09:22,882 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\material\F.txt
# 2026-01-06 07:09:23,041 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\material\F_Y.txt
# 2026-01-06 07:09:23,070 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\material\unit.txt
# 2026-01-06 07:09:23,077 - INFO - 20260106 07:09:23 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\material
# 2026-01-06 07:09:23,078 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\nutrients\F.txt
# 2026-01-06 07:09:23,224 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\nutrients\F_Y.txt
# 2026-01-06 07:09:23,262 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\nutrients\unit.txt
# 2026-01-06 07:09:23,265 - INFO - 20260106 07:09:23 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\nutrients
# 2026-01-06 07:09:23,266 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\water\F.txt
# 2026-01-06 07:09:23,565 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\water\F_Y.txt
# 2026-01-06 07:09:23,608 - INFO - Load data from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\water\unit.txt
# 2026-01-06 07:09:23,623 - INFO - 20260106 07:09:23 - FILEIO -  Added satellite account from C:\Users\louis\Documents\Codes\GAC\OpenIO-Canada\Data\EXIOBASE\IOT_2022_pxp\water
# 2026-01-06 07:09:23,993 - INFO - 20260106 07:09:23 - MODIFICATION -  Changed country names
# 2026-01-06 07:09:23,994 - INFO - Exiobase data loaded successfully
# 2026-01-06 07:09:23,994 - INFO - Calculating all matrices...

# %% [markdown]
# Run the calc() function which will calculate the life cycle impacts of each sector.

# %%
tables.calc()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tables.calc()
#
# NameError: name 'tables' is not defined

# %% [markdown]
# OpenIO-Canada takes a while to run (~45 minutes) on a good machine. To avoid having to re-run the code everytime you want to use openIO-Canada, you can save the whole object in a pickle file.

# %%
import gzip
import pickle

with gzip.open('C:\\Users\\louis\\Documents\\Codes\\GAC\\OpenIO-Canada\\Data\\output_pickle\\openIO_2022_not_endogenized.gz.pickle', 'wb') as file:
    pickle.dump(tables, file)
